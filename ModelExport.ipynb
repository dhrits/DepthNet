# %% [markdown]
# ## Interactively Export Model to ONNX

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from tqdm.notebook import tqdm

from torchvision import datasets, transforms

from torch.optim import lr_scheduler
from torch import tensor
from tqdm.notebook import tqdm

from utils import *
from learner import *
from data import *
from models import *
from criterion import *
from config import *

from dataloaders.nyu import NYUDataset

import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext tensorboard
# %reload_ext autoreload
# %autoreload 2
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
plt.rcParams['figure.figsize'] = (20, 20)

# %%
config = Config()
config.write()

# %%
from torch_lr_finder import LRFinder

# %%
torch.manual_seed(config.seed)
np.random.seed(config.seed)
random.seed(config.seed)

# %%
MODEL_PATH = 'all_data_91.pth'

# %%
model = MobileNetV2SkipAdd(pretrained=True, interpolation='bilinear')

# %%
model.load_state_dict(torch.load(MODEL_PATH, map_location=torch.device('cpu'))['state_dict'])
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# MobileNetV2SkipAdd(
#   (conv0): ConvBNReLU(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (conv1): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv6): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv7): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv8): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv9): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv10): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv11): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv12): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv13): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv14): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv15): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv16): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv17): InvertedResidual(
#     (conv): Sequential(
#       (0): ConvBNReLU(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv18): ConvBNReLU(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvBNReLU(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (decode_conv1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1280, 1280, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1280, bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(1280, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (decode_conv2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (decode_conv3): Sequential(
#     (0): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (decode_conv4): Sequential(
#     (0): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=24, bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (decode_conv5): Sequential(
#     (0): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=16, bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (decode_conv6): Sequential(
#     (0): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
# )

# %%
class Normalizer(nn.Module):
    def __init__(self):
        super(Normalizer, self).__init__()
    def forward(self, x):
        min_rows = x.min(0)
        min = min_rows.min(1)
        max_rows = x.max(0)
        max = max_rows.max(1)
        return 255. * (x - min)/(max - min)
    
def export_model(model, outpath='depth.onnx', inputnames=['images'], outputnames=['depths'], normalize=True):
    dummy_input = torch.randn(1, 3, 224, 224)
    if normalize:
        model = nn.Sequential(model, Normalizer())
    torch.onnx.export(model, dummy_input, outpath, verbose=True, input_names=inputnames, output_names=outputnames)

# %%
export_model(model, 'depth_test.onnx', normalize=False)
# Out:
# /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:912: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(x.shape)
# /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:909: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(x.shape)
# /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:906: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(x.shape)
# /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:914: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(x.shape)
# torch.Size([1, 32, 28, 28])
# torch.Size([1, 24, 56, 56])
# torch.Size([1, 16, 112, 112])
# torch.Size([1, 1, 224, 224])
# /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/onnx/symbolic_helper.py:253: UserWarning: You are trying to export the model with onnx:Upsample for ONNX opset version 9. This operator might cause results to not match the expected results by PyTorch.
# ONNX's Upsample/Resize operator did not match Pytorch's Interpolation until opset 11. Attributes to determine how to transform the input were added in onnx:Resize in opset 11 to support Pytorch's behavior (like coordinate_transformation_mode and nearest_mode).
# We recommend using opset 11 and above for models using this operator.
#   "" + str(_export_onnx_opset_version) + ". "
# graph(%images : Float(1:150528, 3:50176, 224:224, 224:1),
#       %conv0.0.weight : Float(32:27, 3:9, 3:3, 3:1),
#       %conv0.1.weight : Float(32:1),
#       %conv0.1.bias : Float(32:1),
#       %conv0.1.running_mean : Float(32:1),
#       %conv0.1.running_var : Float(32:1),
#       %conv1.conv.0.0.weight : Float(32:9, 1:9, 3:3, 3:1),
#       %conv1.conv.0.1.weight : Float(32:1),
#       %conv1.conv.0.1.bias : Float(32:1),
#       %conv1.conv.0.1.running_mean : Float(32:1),
#       %conv1.conv.0.1.running_var : Float(32:1),
#       %conv1.conv.1.weight : Float(16:32, 32:1, 1:1, 1:1),
#       %conv1.conv.2.weight : Float(16:1),
#       %conv1.conv.2.bias : Float(16:1),
#       %conv1.conv.2.running_mean : Float(16:1),
#       %conv1.conv.2.running_var : Float(16:1),
#       %conv2.conv.0.0.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %conv2.conv.0.1.weight : Float(96:1),
#       %conv2.conv.0.1.bias : Float(96:1),
#       %conv2.conv.0.1.running_mean : Float(96:1),
#       %conv2.conv.0.1.running_var : Float(96:1),
#       %conv2.conv.1.0.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %conv2.conv.1.1.weight : Float(96:1),
#       %conv2.conv.1.1.bias : Float(96:1),
#       %conv2.conv.1.1.running_mean : Float(96:1),
#       %conv2.conv.1.1.running_var : Float(96:1),
#       %conv2.conv.2.weight : Float(24:96, 96:1, 1:1, 1:1),
#       %conv2.conv.3.weight : Float(24:1),
#       %conv2.conv.3.bias : Float(24:1),
#       %conv2.conv.3.running_mean : Float(24:1),
#       %conv2.conv.3.running_var : Float(24:1),
#       %conv3.conv.0.0.weight : Float(144:24, 24:1, 1:1, 1:1),
#       %conv3.conv.0.1.weight : Float(144:1),
#       %conv3.conv.0.1.bias : Float(144:1),
#       %conv3.conv.0.1.running_mean : Float(144:1),
#       %conv3.conv.0.1.running_var : Float(144:1),
#       %conv3.conv.1.0.weight : Float(144:9, 1:9, 3:3, 3:1),
#       %conv3.conv.1.1.weight : Float(144:1),
#       %conv3.conv.1.1.bias : Float(144:1),
#       %conv3.conv.1.1.running_mean : Float(144:1),
#       %conv3.conv.1.1.running_var : Float(144:1),
#       %conv3.conv.2.weight : Float(24:144, 144:1, 1:1, 1:1),
#       %conv3.conv.3.weight : Float(24:1),
#       %conv3.conv.3.bias : Float(24:1),
#       %conv3.conv.3.running_mean : Float(24:1),
#       %conv3.conv.3.running_var : Float(24:1),
#       %conv4.conv.0.0.weight : Float(144:24, 24:1, 1:1, 1:1),
#       %conv4.conv.0.1.weight : Float(144:1),
#       %conv4.conv.0.1.bias : Float(144:1),
#       %conv4.conv.0.1.running_mean : Float(144:1),
#       %conv4.conv.0.1.running_var : Float(144:1),
#       %conv4.conv.1.0.weight : Float(144:9, 1:9, 3:3, 3:1),
#       %conv4.conv.1.1.weight : Float(144:1),
#       %conv4.conv.1.1.bias : Float(144:1),
#       %conv4.conv.1.1.running_mean : Float(144:1),
#       %conv4.conv.1.1.running_var : Float(144:1),
#       %conv4.conv.2.weight : Float(32:144, 144:1, 1:1, 1:1),
#       %conv4.conv.3.weight : Float(32:1),
#       %conv4.conv.3.bias : Float(32:1),
#       %conv4.conv.3.running_mean : Float(32:1),
#       %conv4.conv.3.running_var : Float(32:1),
#       %conv5.conv.0.0.weight : Float(192:32, 32:1, 1:1, 1:1),
#       %conv5.conv.0.1.weight : Float(192:1),
#       %conv5.conv.0.1.bias : Float(192:1),
#       %conv5.conv.0.1.running_mean : Float(192:1),
#       %conv5.conv.0.1.running_var : Float(192:1),
#       %conv5.conv.1.0.weight : Float(192:9, 1:9, 3:3, 3:1),
#       %conv5.conv.1.1.weight : Float(192:1),
#       %conv5.conv.1.1.bias : Float(192:1),
#       %conv5.conv.1.1.running_mean : Float(192:1),
#       %conv5.conv.1.1.running_var : Float(192:1),
#       %conv5.conv.2.weight : Float(32:192, 192:1, 1:1, 1:1),
#       %conv5.conv.3.weight : Float(32:1),
#       %conv5.conv.3.bias : Float(32:1),
#       %conv5.conv.3.running_mean : Float(32:1),
#       %conv5.conv.3.running_var : Float(32:1),
#       %conv6.conv.0.0.weight : Float(192:32, 32:1, 1:1, 1:1),
#       %conv6.conv.0.1.weight : Float(192:1),
#       %conv6.conv.0.1.bias : Float(192:1),
#       %conv6.conv.0.1.running_mean : Float(192:1),
#       %conv6.conv.0.1.running_var : Float(192:1),
#       %conv6.conv.1.0.weight : Float(192:9, 1:9, 3:3, 3:1),
#       %conv6.conv.1.1.weight : Float(192:1),
#       %conv6.conv.1.1.bias : Float(192:1),
#       %conv6.conv.1.1.running_mean : Float(192:1),
#       %conv6.conv.1.1.running_var : Float(192:1),
#       %conv6.conv.2.weight : Float(32:192, 192:1, 1:1, 1:1),
#       %conv6.conv.3.weight : Float(32:1),
#       %conv6.conv.3.bias : Float(32:1),
#       %conv6.conv.3.running_mean : Float(32:1),
#       %conv6.conv.3.running_var : Float(32:1),
#       %conv7.conv.0.0.weight : Float(192:32, 32:1, 1:1, 1:1),
#       %conv7.conv.0.1.weight : Float(192:1),
#       %conv7.conv.0.1.bias : Float(192:1),
#       %conv7.conv.0.1.running_mean : Float(192:1),
#       %conv7.conv.0.1.running_var : Float(192:1),
#       %conv7.conv.1.0.weight : Float(192:9, 1:9, 3:3, 3:1),
#       %conv7.conv.1.1.weight : Float(192:1),
#       %conv7.conv.1.1.bias : Float(192:1),
#       %conv7.conv.1.1.running_mean : Float(192:1),
#       %conv7.conv.1.1.running_var : Float(192:1),
#       %conv7.conv.2.weight : Float(64:192, 192:1, 1:1, 1:1),
#       %conv7.conv.3.weight : Float(64:1),
#       %conv7.conv.3.bias : Float(64:1),
#       %conv7.conv.3.running_mean : Float(64:1),
#       %conv7.conv.3.running_var : Float(64:1),
#       %conv8.conv.0.0.weight : Float(384:64, 64:1, 1:1, 1:1),
#       %conv8.conv.0.1.weight : Float(384:1),
#       %conv8.conv.0.1.bias : Float(384:1),
#       %conv8.conv.0.1.running_mean : Float(384:1),
#       %conv8.conv.0.1.running_var : Float(384:1),
#       %conv8.conv.1.0.weight : Float(384:9, 1:9, 3:3, 3:1),
#       %conv8.conv.1.1.weight : Float(384:1),
#       %conv8.conv.1.1.bias : Float(384:1),
#       %conv8.conv.1.1.running_mean : Float(384:1),
#       %conv8.conv.1.1.running_var : Float(384:1),
#       %conv8.conv.2.weight : Float(64:384, 384:1, 1:1, 1:1),
#       %conv8.conv.3.weight : Float(64:1),
#       %conv8.conv.3.bias : Float(64:1),
#       %conv8.conv.3.running_mean : Float(64:1),
#       %conv8.conv.3.running_var : Float(64:1),
#       %conv9.conv.0.0.weight : Float(384:64, 64:1, 1:1, 1:1),
#       %conv9.conv.0.1.weight : Float(384:1),
#       %conv9.conv.0.1.bias : Float(384:1),
#       %conv9.conv.0.1.running_mean : Float(384:1),
#       %conv9.conv.0.1.running_var : Float(384:1),
#       %conv9.conv.1.0.weight : Float(384:9, 1:9, 3:3, 3:1),
#       %conv9.conv.1.1.weight : Float(384:1),
#       %conv9.conv.1.1.bias : Float(384:1),
#       %conv9.conv.1.1.running_mean : Float(384:1),
#       %conv9.conv.1.1.running_var : Float(384:1),
#       %conv9.conv.2.weight : Float(64:384, 384:1, 1:1, 1:1),
#       %conv9.conv.3.weight : Float(64:1),
#       %conv9.conv.3.bias : Float(64:1),
#       %conv9.conv.3.running_mean : Float(64:1),
#       %conv9.conv.3.running_var : Float(64:1),
#       %conv10.conv.0.0.weight : Float(384:64, 64:1, 1:1, 1:1),
#       %conv10.conv.0.1.weight : Float(384:1),
#       %conv10.conv.0.1.bias : Float(384:1),
#       %conv10.conv.0.1.running_mean : Float(384:1),
#       %conv10.conv.0.1.running_var : Float(384:1),
#       %conv10.conv.1.0.weight : Float(384:9, 1:9, 3:3, 3:1),
#       %conv10.conv.1.1.weight : Float(384:1),
#       %conv10.conv.1.1.bias : Float(384:1),
#       %conv10.conv.1.1.running_mean : Float(384:1),
#       %conv10.conv.1.1.running_var : Float(384:1),
#       %conv10.conv.2.weight : Float(64:384, 384:1, 1:1, 1:1),
#       %conv10.conv.3.weight : Float(64:1),
#       %conv10.conv.3.bias : Float(64:1),
#       %conv10.conv.3.running_mean : Float(64:1),
#       %conv10.conv.3.running_var : Float(64:1),
#       %conv11.conv.0.0.weight : Float(384:64, 64:1, 1:1, 1:1),
#       %conv11.conv.0.1.weight : Float(384:1),
#       %conv11.conv.0.1.bias : Float(384:1),
#       %conv11.conv.0.1.running_mean : Float(384:1),
#       %conv11.conv.0.1.running_var : Float(384:1),
#       %conv11.conv.1.0.weight : Float(384:9, 1:9, 3:3, 3:1),
#       %conv11.conv.1.1.weight : Float(384:1),
#       %conv11.conv.1.1.bias : Float(384:1),
#       %conv11.conv.1.1.running_mean : Float(384:1),
#       %conv11.conv.1.1.running_var : Float(384:1),
#       %conv11.conv.2.weight : Float(96:384, 384:1, 1:1, 1:1),
#       %conv11.conv.3.weight : Float(96:1),
#       %conv11.conv.3.bias : Float(96:1),
#       %conv11.conv.3.running_mean : Float(96:1),
#       %conv11.conv.3.running_var : Float(96:1),
#       %conv12.conv.0.0.weight : Float(576:96, 96:1, 1:1, 1:1),
#       %conv12.conv.0.1.weight : Float(576:1),
#       %conv12.conv.0.1.bias : Float(576:1),
#       %conv12.conv.0.1.running_mean : Float(576:1),
#       %conv12.conv.0.1.running_var : Float(576:1),
#       %conv12.conv.1.0.weight : Float(576:9, 1:9, 3:3, 3:1),
#       %conv12.conv.1.1.weight : Float(576:1),
#       %conv12.conv.1.1.bias : Float(576:1),
#       %conv12.conv.1.1.running_mean : Float(576:1),
#       %conv12.conv.1.1.running_var : Float(576:1),
#       %conv12.conv.2.weight : Float(96:576, 576:1, 1:1, 1:1),
#       %conv12.conv.3.weight : Float(96:1),
#       %conv12.conv.3.bias : Float(96:1),
#       %conv12.conv.3.running_mean : Float(96:1),
#       %conv12.conv.3.running_var : Float(96:1),
#       %conv13.conv.0.0.weight : Float(576:96, 96:1, 1:1, 1:1),
#       %conv13.conv.0.1.weight : Float(576:1),
#       %conv13.conv.0.1.bias : Float(576:1),
#       %conv13.conv.0.1.running_mean : Float(576:1),
#       %conv13.conv.0.1.running_var : Float(576:1),
#       %conv13.conv.1.0.weight : Float(576:9, 1:9, 3:3, 3:1),
#       %conv13.conv.1.1.weight : Float(576:1),
#       %conv13.conv.1.1.bias : Float(576:1),
#       %conv13.conv.1.1.running_mean : Float(576:1),
#       %conv13.conv.1.1.running_var : Float(576:1),
#       %conv13.conv.2.weight : Float(96:576, 576:1, 1:1, 1:1),
#       %conv13.conv.3.weight : Float(96:1),
#       %conv13.conv.3.bias : Float(96:1),
#       %conv13.conv.3.running_mean : Float(96:1),
#       %conv13.conv.3.running_var : Float(96:1),
#       %conv14.conv.0.0.weight : Float(576:96, 96:1, 1:1, 1:1),
#       %conv14.conv.0.1.weight : Float(576:1),
#       %conv14.conv.0.1.bias : Float(576:1),
#       %conv14.conv.0.1.running_mean : Float(576:1),
#       %conv14.conv.0.1.running_var : Float(576:1),
#       %conv14.conv.1.0.weight : Float(576:9, 1:9, 3:3, 3:1),
#       %conv14.conv.1.1.weight : Float(576:1),
#       %conv14.conv.1.1.bias : Float(576:1),
#       %conv14.conv.1.1.running_mean : Float(576:1),
#       %conv14.conv.1.1.running_var : Float(576:1),
#       %conv14.conv.2.weight : Float(160:576, 576:1, 1:1, 1:1),
#       %conv14.conv.3.weight : Float(160:1),
#       %conv14.conv.3.bias : Float(160:1),
#       %conv14.conv.3.running_mean : Float(160:1),
#       %conv14.conv.3.running_var : Float(160:1),
#       %conv15.conv.0.0.weight : Float(960:160, 160:1, 1:1, 1:1),
#       %conv15.conv.0.1.weight : Float(960:1),
#       %conv15.conv.0.1.bias : Float(960:1),
#       %conv15.conv.0.1.running_mean : Float(960:1),
#       %conv15.conv.0.1.running_var : Float(960:1),
#       %conv15.conv.1.0.weight : Float(960:9, 1:9, 3:3, 3:1),
#       %conv15.conv.1.1.weight : Float(960:1),
#       %conv15.conv.1.1.bias : Float(960:1),
#       %conv15.conv.1.1.running_mean : Float(960:1),
#       %conv15.conv.1.1.running_var : Float(960:1),
#       %conv15.conv.2.weight : Float(160:960, 960:1, 1:1, 1:1),
#       %conv15.conv.3.weight : Float(160:1),
#       %conv15.conv.3.bias : Float(160:1),
#       %conv15.conv.3.running_mean : Float(160:1),
#       %conv15.conv.3.running_var : Float(160:1),
#       %conv16.conv.0.0.weight : Float(960:160, 160:1, 1:1, 1:1),
#       %conv16.conv.0.1.weight : Float(960:1),
#       %conv16.conv.0.1.bias : Float(960:1),
#       %conv16.conv.0.1.running_mean : Float(960:1),
#       %conv16.conv.0.1.running_var : Float(960:1),
#       %conv16.conv.1.0.weight : Float(960:9, 1:9, 3:3, 3:1),
#       %conv16.conv.1.1.weight : Float(960:1),
#       %conv16.conv.1.1.bias : Float(960:1),
#       %conv16.conv.1.1.running_mean : Float(960:1),
#       %conv16.conv.1.1.running_var : Float(960:1),
#       %conv16.conv.2.weight : Float(160:960, 960:1, 1:1, 1:1),
#       %conv16.conv.3.weight : Float(160:1),
#       %conv16.conv.3.bias : Float(160:1),
#       %conv16.conv.3.running_mean : Float(160:1),
#       %conv16.conv.3.running_var : Float(160:1),
#       %conv17.conv.0.0.weight : Float(960:160, 160:1, 1:1, 1:1),
#       %conv17.conv.0.1.weight : Float(960:1),
#       %conv17.conv.0.1.bias : Float(960:1),
#       %conv17.conv.0.1.running_mean : Float(960:1),
#       %conv17.conv.0.1.running_var : Float(960:1),
#       %conv17.conv.1.0.weight : Float(960:9, 1:9, 3:3, 3:1),
#       %conv17.conv.1.1.weight : Float(960:1),
#       %conv17.conv.1.1.bias : Float(960:1),
#       %conv17.conv.1.1.running_mean : Float(960:1),
#       %conv17.conv.1.1.running_var : Float(960:1),
#       %conv17.conv.2.weight : Float(320:960, 960:1, 1:1, 1:1),
#       %conv17.conv.3.weight : Float(320:1),
#       %conv17.conv.3.bias : Float(320:1),
#       %conv17.conv.3.running_mean : Float(320:1),
#       %conv17.conv.3.running_var : Float(320:1),
#       %conv18.0.weight : Float(1280:320, 320:1, 1:1, 1:1),
#       %conv18.1.weight : Float(1280:1),
#       %conv18.1.bias : Float(1280:1),
#       %conv18.1.running_mean : Float(1280:1),
#       %conv18.1.running_var : Float(1280:1),
#       %decode_conv1.0.0.weight : Float(1280:25, 1:25, 5:5, 5:1),
#       %decode_conv1.0.1.weight : Float(1280:1),
#       %decode_conv1.0.1.bias : Float(1280:1),
#       %decode_conv1.0.1.running_mean : Float(1280:1),
#       %decode_conv1.0.1.running_var : Float(1280:1),
#       %decode_conv1.1.0.weight : Float(512:1280, 1280:1, 1:1, 1:1),
#       %decode_conv1.1.1.weight : Float(512:1),
#       %decode_conv1.1.1.bias : Float(512:1),
#       %decode_conv1.1.1.running_mean : Float(512:1),
#       %decode_conv1.1.1.running_var : Float(512:1),
#       %decode_conv2.0.0.weight : Float(512:25, 1:25, 5:5, 5:1),
#       %decode_conv2.0.1.weight : Float(512:1),
#       %decode_conv2.0.1.bias : Float(512:1),
#       %decode_conv2.0.1.running_mean : Float(512:1),
#       %decode_conv2.0.1.running_var : Float(512:1),
#       %decode_conv2.1.0.weight : Float(32:512, 512:1, 1:1, 1:1),
#       %decode_conv2.1.1.weight : Float(32:1),
#       %decode_conv2.1.1.bias : Float(32:1),
#       %decode_conv2.1.1.running_mean : Float(32:1),
#       %decode_conv2.1.1.running_var : Float(32:1),
#       %decode_conv3.0.0.weight : Float(32:25, 1:25, 5:5, 5:1),
#       %decode_conv3.0.1.weight : Float(32:1),
#       %decode_conv3.0.1.bias : Float(32:1),
#       %decode_conv3.0.1.running_mean : Float(32:1),
#       %decode_conv3.0.1.running_var : Float(32:1),
#       %decode_conv3.1.0.weight : Float(24:32, 32:1, 1:1, 1:1),
#       %decode_conv3.1.1.weight : Float(24:1),
#       %decode_conv3.1.1.bias : Float(24:1),
#       %decode_conv3.1.1.running_mean : Float(24:1),
#       %decode_conv3.1.1.running_var : Float(24:1),
#       %decode_conv4.0.0.weight : Float(24:25, 1:25, 5:5, 5:1),
#       %decode_conv4.0.1.weight : Float(24:1),
#       %decode_conv4.0.1.bias : Float(24:1),
#       %decode_conv4.0.1.running_mean : Float(24:1),
#       %decode_conv4.0.1.running_var : Float(24:1),
#       %decode_conv4.1.0.weight : Float(16:24, 24:1, 1:1, 1:1),
#       %decode_conv4.1.1.weight : Float(16:1),
#       %decode_conv4.1.1.bias : Float(16:1),
#       %decode_conv4.1.1.running_mean : Float(16:1),
#       %decode_conv4.1.1.running_var : Float(16:1),
#       %decode_conv5.0.0.weight : Float(16:25, 1:25, 5:5, 5:1),
#       %decode_conv5.0.1.weight : Float(16:1),
#       %decode_conv5.0.1.bias : Float(16:1),
#       %decode_conv5.0.1.running_mean : Float(16:1),
#       %decode_conv5.0.1.running_var : Float(16:1),
#       %decode_conv5.1.0.weight : Float(32:16, 16:1, 1:1, 1:1),
#       %decode_conv5.1.1.weight : Float(32:1),
#       %decode_conv5.1.1.bias : Float(32:1),
#       %decode_conv5.1.1.running_mean : Float(32:1),
#       %decode_conv5.1.1.running_var : Float(32:1),
#       %decode_conv6.0.weight : Float(1:32, 32:1, 1:1, 1:1),
#       %decode_conv6.1.weight : Float(1:1),
#       %decode_conv6.1.bias : Float(1:1),
#       %decode_conv6.1.running_mean : Float(1:1),
#       %decode_conv6.1.running_var : Float(1:1),
#       %613 : Float(4:1),
#       %618 : Float(4:1),
#       %623 : Float(4:1),
#       %628 : Float(4:1),
#       %633 : Float(4:1)):
#   %379 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%images, %conv0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %380 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%379, %conv0.1.weight, %conv0.1.bias, %conv0.1.running_mean, %conv0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %381 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Clip[max=6., min=0.](%380) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %382 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%381, %conv1.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %383 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%382, %conv1.conv.0.1.weight, %conv1.conv.0.1.bias, %conv1.conv.0.1.running_mean, %conv1.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %384 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Clip[max=6., min=0.](%383) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %385 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%384, %conv1.conv.1.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %386 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%385, %conv1.conv.2.weight, %conv1.conv.2.bias, %conv1.conv.2.running_mean, %conv1.conv.2.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %387 : Float(1:1204224, 96:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%386, %conv2.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %388 : Float(1:1204224, 96:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%387, %conv2.conv.0.1.weight, %conv2.conv.0.1.bias, %conv2.conv.0.1.running_mean, %conv2.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %389 : Float(1:1204224, 96:12544, 112:112, 112:1) = onnx::Clip[max=6., min=0.](%388) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %390 : Float(1:301056, 96:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%389, %conv2.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %391 : Float(1:301056, 96:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%390, %conv2.conv.1.1.weight, %conv2.conv.1.1.bias, %conv2.conv.1.1.running_mean, %conv2.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %392 : Float(1:301056, 96:3136, 56:56, 56:1) = onnx::Clip[max=6., min=0.](%391) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %393 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%392, %conv2.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %394 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%393, %conv2.conv.3.weight, %conv2.conv.3.bias, %conv2.conv.3.running_mean, %conv2.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %395 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%394, %conv3.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %396 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%395, %conv3.conv.0.1.weight, %conv3.conv.0.1.bias, %conv3.conv.0.1.running_mean, %conv3.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %397 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Clip[max=6., min=0.](%396) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %398 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=144, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%397, %conv3.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %399 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%398, %conv3.conv.1.1.weight, %conv3.conv.1.1.bias, %conv3.conv.1.1.running_mean, %conv3.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %400 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Clip[max=6., min=0.](%399) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %401 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%400, %conv3.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %402 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%401, %conv3.conv.3.weight, %conv3.conv.3.bias, %conv3.conv.3.running_mean, %conv3.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %403 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Add(%394, %402) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %404 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%403, %conv4.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %405 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%404, %conv4.conv.0.1.weight, %conv4.conv.0.1.bias, %conv4.conv.0.1.running_mean, %conv4.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %406 : Float(1:451584, 144:3136, 56:56, 56:1) = onnx::Clip[max=6., min=0.](%405) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %407 : Float(1:112896, 144:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=144, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%406, %conv4.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %408 : Float(1:112896, 144:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%407, %conv4.conv.1.1.weight, %conv4.conv.1.1.bias, %conv4.conv.1.1.running_mean, %conv4.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %409 : Float(1:112896, 144:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%408) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %410 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%409, %conv4.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %411 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%410, %conv4.conv.3.weight, %conv4.conv.3.bias, %conv4.conv.3.running_mean, %conv4.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %412 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%411, %conv5.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %413 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%412, %conv5.conv.0.1.weight, %conv5.conv.0.1.bias, %conv5.conv.0.1.running_mean, %conv5.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %414 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%413) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %415 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%414, %conv5.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %416 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%415, %conv5.conv.1.1.weight, %conv5.conv.1.1.bias, %conv5.conv.1.1.running_mean, %conv5.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %417 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%416) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %418 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%417, %conv5.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %419 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%418, %conv5.conv.3.weight, %conv5.conv.3.bias, %conv5.conv.3.running_mean, %conv5.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %420 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Add(%411, %419) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %421 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%420, %conv6.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %422 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%421, %conv6.conv.0.1.weight, %conv6.conv.0.1.bias, %conv6.conv.0.1.running_mean, %conv6.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %423 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%422) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %424 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%423, %conv6.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %425 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%424, %conv6.conv.1.1.weight, %conv6.conv.1.1.bias, %conv6.conv.1.1.running_mean, %conv6.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %426 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%425) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %427 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%426, %conv6.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %428 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%427, %conv6.conv.3.weight, %conv6.conv.3.bias, %conv6.conv.3.running_mean, %conv6.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %429 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Add(%420, %428) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %430 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%429, %conv7.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %431 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%430, %conv7.conv.0.1.weight, %conv7.conv.0.1.bias, %conv7.conv.0.1.running_mean, %conv7.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %432 : Float(1:150528, 192:784, 28:28, 28:1) = onnx::Clip[max=6., min=0.](%431) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %433 : Float(1:37632, 192:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=192, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%432, %conv7.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %434 : Float(1:37632, 192:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%433, %conv7.conv.1.1.weight, %conv7.conv.1.1.bias, %conv7.conv.1.1.running_mean, %conv7.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %435 : Float(1:37632, 192:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%434) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %436 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%435, %conv7.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %437 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%436, %conv7.conv.3.weight, %conv7.conv.3.bias, %conv7.conv.3.running_mean, %conv7.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %438 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%437, %conv8.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %439 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%438, %conv8.conv.0.1.weight, %conv8.conv.0.1.bias, %conv8.conv.0.1.running_mean, %conv8.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %440 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%439) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %441 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%440, %conv8.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %442 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%441, %conv8.conv.1.1.weight, %conv8.conv.1.1.bias, %conv8.conv.1.1.running_mean, %conv8.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %443 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%442) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %444 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%443, %conv8.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %445 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%444, %conv8.conv.3.weight, %conv8.conv.3.bias, %conv8.conv.3.running_mean, %conv8.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %446 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Add(%437, %445) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %447 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%446, %conv9.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %448 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%447, %conv9.conv.0.1.weight, %conv9.conv.0.1.bias, %conv9.conv.0.1.running_mean, %conv9.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %449 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%448) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %450 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%449, %conv9.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %451 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%450, %conv9.conv.1.1.weight, %conv9.conv.1.1.bias, %conv9.conv.1.1.running_mean, %conv9.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %452 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%451) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %453 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%452, %conv9.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %454 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%453, %conv9.conv.3.weight, %conv9.conv.3.bias, %conv9.conv.3.running_mean, %conv9.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %455 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Add(%446, %454) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %456 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%455, %conv10.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %457 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%456, %conv10.conv.0.1.weight, %conv10.conv.0.1.bias, %conv10.conv.0.1.running_mean, %conv10.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %458 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%457) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %459 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%458, %conv10.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %460 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%459, %conv10.conv.1.1.weight, %conv10.conv.1.1.bias, %conv10.conv.1.1.running_mean, %conv10.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %461 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%460) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %462 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%461, %conv10.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %463 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%462, %conv10.conv.3.weight, %conv10.conv.3.bias, %conv10.conv.3.running_mean, %conv10.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %464 : Float(1:12544, 64:196, 14:14, 14:1) = onnx::Add(%455, %463) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %465 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%464, %conv11.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %466 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%465, %conv11.conv.0.1.weight, %conv11.conv.0.1.bias, %conv11.conv.0.1.running_mean, %conv11.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %467 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%466) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %468 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=384, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%467, %conv11.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %469 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%468, %conv11.conv.1.1.weight, %conv11.conv.1.1.bias, %conv11.conv.1.1.running_mean, %conv11.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %470 : Float(1:75264, 384:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%469) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %471 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%470, %conv11.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %472 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%471, %conv11.conv.3.weight, %conv11.conv.3.bias, %conv11.conv.3.running_mean, %conv11.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %473 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%472, %conv12.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %474 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%473, %conv12.conv.0.1.weight, %conv12.conv.0.1.bias, %conv12.conv.0.1.running_mean, %conv12.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %475 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%474) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %476 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=576, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%475, %conv12.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %477 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%476, %conv12.conv.1.1.weight, %conv12.conv.1.1.bias, %conv12.conv.1.1.running_mean, %conv12.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %478 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%477) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %479 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%478, %conv12.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %480 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%479, %conv12.conv.3.weight, %conv12.conv.3.bias, %conv12.conv.3.running_mean, %conv12.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %481 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::Add(%472, %480) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %482 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%481, %conv13.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %483 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%482, %conv13.conv.0.1.weight, %conv13.conv.0.1.bias, %conv13.conv.0.1.running_mean, %conv13.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %484 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%483) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %485 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=576, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%484, %conv13.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %486 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%485, %conv13.conv.1.1.weight, %conv13.conv.1.1.bias, %conv13.conv.1.1.running_mean, %conv13.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %487 : Float(1:112896, 576:196, 14:14, 14:1) = onnx::Clip[max=6., min=0.](%486) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %488 : Float(1:18816, 96:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%487, %conv13.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
# ...
#   %506 : Float(1:7840, 160:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%505, %conv15.conv.3.weight, %conv15.conv.3.bias, %conv15.conv.3.running_mean, %conv15.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %507 : Float(1:7840, 160:49, 7:7, 7:1) = onnx::Add(%498, %506) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %508 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%507, %conv16.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %509 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%508, %conv16.conv.0.1.weight, %conv16.conv.0.1.bias, %conv16.conv.0.1.running_mean, %conv16.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %510 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Clip[max=6., min=0.](%509) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %511 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=960, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%510, %conv16.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %512 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%511, %conv16.conv.1.1.weight, %conv16.conv.1.1.bias, %conv16.conv.1.1.running_mean, %conv16.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %513 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Clip[max=6., min=0.](%512) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %514 : Float(1:7840, 160:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%513, %conv16.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %515 : Float(1:7840, 160:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%514, %conv16.conv.3.weight, %conv16.conv.3.bias, %conv16.conv.3.running_mean, %conv16.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %516 : Float(1:7840, 160:49, 7:7, 7:1) = onnx::Add(%507, %515) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torchvision/models/mobilenet.py:72:0
#   %517 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%516, %conv17.conv.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %518 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%517, %conv17.conv.0.1.weight, %conv17.conv.0.1.bias, %conv17.conv.0.1.running_mean, %conv17.conv.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %519 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Clip[max=6., min=0.](%518) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %520 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=960, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%519, %conv17.conv.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %521 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%520, %conv17.conv.1.1.weight, %conv17.conv.1.1.bias, %conv17.conv.1.1.running_mean, %conv17.conv.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %522 : Float(1:47040, 960:49, 7:7, 7:1) = onnx::Clip[max=6., min=0.](%521) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %523 : Float(1:15680, 320:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%522, %conv17.conv.2.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %524 : Float(1:15680, 320:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%523, %conv17.conv.3.weight, %conv17.conv.3.bias, %conv17.conv.3.running_mean, %conv17.conv.3.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %525 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%524, %conv18.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %526 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%525, %conv18.1.weight, %conv18.1.bias, %conv18.1.running_mean, %conv18.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %527 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::Clip[max=6., min=0.](%526) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1171:0
#   %528 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1280, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%527, %decode_conv1.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %529 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%528, %decode_conv1.0.1.weight, %decode_conv1.0.1.bias, %decode_conv1.0.1.running_mean, %decode_conv1.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %530 : Float(1:62720, 1280:49, 7:7, 7:1) = onnx::Relu(%529) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %531 : Float(1:25088, 512:49, 7:7, 7:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%530, %decode_conv1.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %532 : Float(1:25088, 512:49, 7:7, 7:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%531, %decode_conv1.1.1.weight, %decode_conv1.1.1.bias, %decode_conv1.1.1.running_mean, %decode_conv1.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %533 : Float(1:25088, 512:49, 7:7, 7:1) = onnx::Relu(%532) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %542 : Float(1:100352, 512:196, 14:14, 14:1) = onnx::Upsample[mode="linear"](%533, %613) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3163:0
#   %543 : Float(1:100352, 512:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=512, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%542, %decode_conv2.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %544 : Float(1:100352, 512:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%543, %decode_conv2.0.1.weight, %decode_conv2.0.1.bias, %decode_conv2.0.1.running_mean, %decode_conv2.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %545 : Float(1:100352, 512:196, 14:14, 14:1) = onnx::Relu(%544) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %546 : Float(1:6272, 32:196, 14:14, 14:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%545, %decode_conv2.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %547 : Float(1:6272, 32:196, 14:14, 14:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%546, %decode_conv2.1.1.weight, %decode_conv2.1.1.bias, %decode_conv2.1.1.running_mean, %decode_conv2.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %548 : Float(1:6272, 32:196, 14:14, 14:1) = onnx::Relu(%547) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %557 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Upsample[mode="linear"](%548, %618) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3163:0
#   %558 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Add(%557, %429) # /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:911:0
#   %559 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%558, %decode_conv3.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %560 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%559, %decode_conv3.0.1.weight, %decode_conv3.0.1.bias, %decode_conv3.0.1.running_mean, %decode_conv3.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %561 : Float(1:25088, 32:784, 28:28, 28:1) = onnx::Relu(%560) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %562 : Float(1:18816, 24:784, 28:28, 28:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%561, %decode_conv3.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %563 : Float(1:18816, 24:784, 28:28, 28:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%562, %decode_conv3.1.1.weight, %decode_conv3.1.1.bias, %decode_conv3.1.1.running_mean, %decode_conv3.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %564 : Float(1:18816, 24:784, 28:28, 28:1) = onnx::Relu(%563) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %573 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Upsample[mode="linear"](%564, %623) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3163:0
#   %574 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Add(%573, %403) # /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:908:0
#   %575 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=24, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%574, %decode_conv4.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %576 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%575, %decode_conv4.0.1.weight, %decode_conv4.0.1.bias, %decode_conv4.0.1.running_mean, %decode_conv4.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %577 : Float(1:75264, 24:3136, 56:56, 56:1) = onnx::Relu(%576) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %578 : Float(1:50176, 16:3136, 56:56, 56:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%577, %decode_conv4.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %579 : Float(1:50176, 16:3136, 56:56, 56:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%578, %decode_conv4.1.1.weight, %decode_conv4.1.1.bias, %decode_conv4.1.1.running_mean, %decode_conv4.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %580 : Float(1:50176, 16:3136, 56:56, 56:1) = onnx::Relu(%579) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %589 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::Upsample[mode="linear"](%580, %628) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3163:0
#   %590 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::Add(%589, %386) # /Users/dhritiman.sagar/Snapchat/Dev/DepthNet/models.py:905:0
#   %591 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=16, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%590, %decode_conv5.0.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %592 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%591, %decode_conv5.0.1.weight, %decode_conv5.0.1.bias, %decode_conv5.0.1.running_mean, %decode_conv5.0.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %593 : Float(1:200704, 16:12544, 112:112, 112:1) = onnx::Relu(%592) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %594 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%593, %decode_conv5.1.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %595 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%594, %decode_conv5.1.1.weight, %decode_conv5.1.1.bias, %decode_conv5.1.1.running_mean, %decode_conv5.1.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %596 : Float(1:401408, 32:12544, 112:112, 112:1) = onnx::Relu(%595) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   %605 : Float(1:1605632, 32:50176, 224:224, 224:1) = onnx::Upsample[mode="linear"](%596, %633) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:3163:0
#   %606 : Float(1:50176, 1:50176, 224:224, 224:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%605, %decode_conv6.0.weight) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %607 : Float(1:50176, 1:50176, 224:224, 224:1) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%606, %decode_conv6.1.weight, %decode_conv6.1.bias, %decode_conv6.1.running_mean, %decode_conv6.1.running_var) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %depths : Float(1:50176, 1:50176, 224:224, 224:1) = onnx::Relu(%607) # /Users/dhritiman.sagar/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1117:0
#   return (%depths)

# %%
dummy_input = torch.randn(1, 3, 224, 224)

# %%
import PIL
from PIL import Image
import torchvision.transforms.functional as F
import onnxruntime as ort

# %%
img = Image.open('test_image.jpeg')
img = F.to_tensor(F.resize(img, (224, 224), interpolation=Image.BILINEAR)).unsqueeze(0).numpy()

# %%
session = ort.InferenceSession('depth_test.onnx')

# %%
outputs = session.run(None, {'images': img})

# %%
depth = outputs[0].reshape(224, 224)

# %%
plt.imshow(depth, cmap='gray')

# %%
plt.imshow(Image.open('test_image.jpeg'))

# %%
import cv2
# Out:
# True

# %%
depth_normalized = np.uint8((depth - np.min(depth))/(np.max(depth) - np.min(depth)) * 255)

# %%
cv2.imwrite('depth_test.png', depth_normalized)
# Out:
# True
